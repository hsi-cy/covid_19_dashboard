# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_csv('confirmed.csv').drop('Unnamed: 0',axis=1)
df1 = pd.read_csv('deaths.csv').drop('Unnamed: 0', axis=1)

# %%
forPlot = pd.DataFrame()

# %%
forPlot['Date'] = df['Date']
forPlot['Confirmed'] = df['United Kingdom']
forPlot['Deaths'] = df1['United Kingdom']

# %%
forPlot.head()
# Out:
#       Date  Confirmed  Deaths
# 0  1/22/20          0       0
# 1  1/23/20          0       0
# 2  1/24/20          0       0
# 3  1/25/20          0       0
# 4  1/26/20          0       0

# %%
from plotly.subplots import make_subplots

import plotly.graph_objects as go

fig = make_subplots(rows=1)
fig.add_bar(x=forPlot['Date'],y=forPlot['Confirmed'],marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                      marker_line_width=1.5, opacity=0.6, name='Confirmed')
fig.add_bar(x=forPlot['Date'], y=forPlot['Deaths'], marker_color='rgb(255,102,102)', marker_line_color='rgb(255,102,102)',
                      marker_line_width=1.5, opacity=0.6,name='Deaths')
# Out:
# <div>                            <div id="74d2924e-682d-4f61-9fba-72cb421aabb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74d2924e-682d-4f61-9fba-72cb421aabb0")) {                    Plotly.newPlot(                        "74d2924e-682d-4f61-9fba-72cb421aabb0",                        [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "Confirmed", "opacity": 0.6, "type": "bar", "x": ["1/22/20", "1/23/20", "1/24/20", "1/25/20", "1/26/20", "1/27/20", "1/28/20", "1/29/20", "1/30/20", "1/31/20", "2/1/20", "2/2/20", "2/3/20", "2/4/20", "2/5/20", "2/6/20", "2/7/20", "2/8/20", "2/9/20", "2/10/20", "2/11/20", "2/12/20", "2/13/20", "2/14/20", "2/15/20", "2/16/20", "2/17/20", "2/18/20", "2/19/20", "2/20/2
# ...
